# %% [markdown]
# "Find euclidean distances for all songs and try it with different features."

# %%
#1. Import Modules:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import euclidean_distances

# %%
#2.Read .csv, clean csv from useless DataTypes, nail the job:
tensongs = pd.read_csv(r'df_audio_features_10.csv')
tensongs # see what to drop
# Drop columns with shitty DataTypes:
somecolumnswereshit = tensongs[["danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "duration_ms"]]
somecolumnswereshit #see if it works
# Tried to insert songnames as index, but failed
epicsolution = pd.DataFrame(euclidean_distances(somecolumnswereshit), index=somecolumnswereshit.index, columns=somecolumnswereshit.index)
epicsolution
# gg ez
# Out:
#                0              1              2              3              4  \
# 0       0.000000   14573.008289   86373.004024   19214.006953   96506.007932
# 1   14573.008289       0.000000   71800.011435   33787.011459   81933.018075
# 2   86373.004024   71800.011435       0.000000  105587.000950   10133.013478
# 3   19214.006953   33787.011459  105587.000950       0.000000  115720.003978
# 4   96506.007932   81933.018075   10133.013478  115720.003978       0.000000
# 5   49851.008398   64424.015061  136224.000197   30637.006573  146357.000380
# 6  139947.000719  154520.002592  226320.000340  120733.000183  236453.001515
# 7   94967.000737  109540.002803  181340.000693   75753.000175  191473.002481
# 8  188973.011453  174400.007754  102600.034253  208187.011705   92467.054223
# 9   30346.063953   15773.071995   56027.060661   49560.047051   66160.073217
#
#                5              6              7              8              9
# ...

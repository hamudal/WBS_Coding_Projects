# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# So, we have our .csv files of the songs, one time with 1000, the other time with 5000 songs and what we maybe come up with later to have fun.
# Our learning platform also provides us with further information about the columns:
#
# **acousticness** - A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic. - *Float*
# **danceability** - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.	- *Float*
# **duration_ms** - The duration of the track in milliseconds. - *Integer*
# **energy** - Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy. - *Float*
# **instrumentalness** - Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0. - *Float*
# **key** - The key the track is in. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. - *Integer*
# **liveness** Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live. - *Float*
# **loudness** - The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db. - *Float*
# **mode** - Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0. - *Integer*
# **speechiness** - Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks. - *Float*
# **tempo** - The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration. - *Float*
# **time_signature** - An estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure). - *Integer*
# **valence** - A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).	*Float*
#
# We now have to choose which columns are worth to keep based on these informations and our own thoughts about it and store them in a new dataframe we even might want to turn into a .csv.

# %% [markdown]
# ## **1. Importing the needed modules and .csv files**

# %%
# We want pandas and our scaler:
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
# We keep .csv files in same path as our project so we easy navigate to them:
df_1000 = pd.read_csv(r'df_audio_features_1000.csv')
df_5000 = pd.read_csv(r'df_audio_features_5000.csv',skipinitialspace=True)

# %% [markdown]
# ## **2. Inspecting the DataFrame to Clean it**

# %%
#Basic pandas stuff:
# df_1000.info() # Put/Remove comment to read/see
df_1000.sample(5) # Put/Remove comment to read/see
# df_5000.sample(5) # Put/Remove comment to read/see
# Out:
#                                                    name           artist  \
# 83                            Hallelujah, I Love Her So      Ray Charles
# 519                          Who Am I (What's My Name)?       Snoop Dogg
# 790                                   Goodbye, Old Girl       Art Farmer
# 1253                                              Picky     Joey Montana
# 1428  Also sprach Zarathustra, Op.30, TrV 176: Prelu...  Richard Strauss
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 83           0.696  0.5470    5    -5.954     0       0.1690      0.792000
# 519          0.692  0.8330    7    -3.974     1       0.0492      0.000136
# 790          0.450  0.0288    7   -17.388     1       0.0467      0.994000
# 1253         0.783  0.7480    8    -4.683     1       0.0892      0.147000
# 1428         0.115  0.3010    0   -13.321     1       0.0449      0.637000
#
#       instrumentalness  liveness  valence    tempo  type  duration_ms  \
# 83             0.00000     0.155   0.6230   73.203   NaN       155507
# 519            0.00002     0.515   0.6920   96.814   NaN       246320
# 790            0.89500     0.118   0.3580  130.838   NaN       274333
# 1253           0.00000     0.173   0.8060   93.222   NaN       182747
# 1428           0.93500     0.154   0.0409   77.276   NaN       109667
#
#       time_signature                      id  \
# 83                 4  5P11rW6aJErF37MTfRZS31
# 519                4  5XhkV07Vou38wnrzwURUOC
# 790                4  5eFFsShr8vchESCk8HGxvn
# 1253               4  4tPL9PeVZY4c0jUPtSD5nx
# 1428               4  3SOZcwfezNCWKs2vukSELD
#
#                                                    html
# 83    https://open.spotify.com/track/5P11rW6aJErF37M...
# 519   https://open.spotify.com/track/5XhkV07Vou38wnr...
# 790   https://open.spotify.com/track/5eFFsShr8vchESC...
# 1253  https://open.spotify.com/track/4tPL9PeVZY4c0jU...
# 1428  https://open.spotify.com/track/3SOZcwfezNCWKs2...

# %% [markdown]
# ### Conclusion here:
# * we want to combine artist and name into one column (might be covers on some datasets)
# * drop the other 2 columns with Dtype = object ('id','html'), we need only numbers...
# * drop 'key', 'mode', 'type', 'duration_ms', 'time_signature', since they seem meaningless for us.

# %% [markdown]
# ## **3. Preparing the data:**
# ### **3.1 1000 songs df:**

# %%
# New column 'title' to get rid of 2 objects:
df_1000['title'] = df_1000['name'] + ' - ' + df_1000['artist']
# Drop a bunch of stuff:
# df_1000.drop(['artist','name','id','html','type','duration_ms']) # cant find the freaking typo - can aswell create a sorted:
clustersongs_1000 = df_1000[['title','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','time_signature','valence','tempo']]
# clustersongs_1000.sample(1) # See how it worked
clustersongs_1000.set_index('title', inplace=True)
# convert into (unmodified) .csv to work with in exploration:
clustersongs_1000.to_csv('1000songs.csv')

# %% [markdown]
# ### **3.2 5000 songs df**:

# %%
df_5000.columns = df_5000.columns.str.strip()
df_5000['title'] = df_5000['name'] + ' - ' + df_5000['artist']
clustersongs_5000 = df_5000[['title','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','time_signature','valence','tempo']]
clustersongs_5000.set_index('title', inplace=True)
clustersongs_5000.to_csv('5000songs.csv')

# %% [markdown]
# ## **4. Different Scaler:**

# %% [markdown]
# ### **4.1 MinMax:**

# %%
# Taken from learning platform:
# initialize the transformer (optionally, set parameters)
my_min_max = MinMaxScaler(feature_range=(0,1)) 
# fit the transformer to the data
my_min_max.fit(clustersongs_1000)
# use the transformer to transform the data
minmax_1000_df = my_min_max.transform(clustersongs_1000) 
# reconvert the transformed data back to a DataFrame
minmax_1000 = pd.DataFrame(minmax_1000_df,
              index=clustersongs_1000.index,
              columns=clustersongs_1000.columns)
# make .csv for next notebook
minmax_1000.to_csv('1000min_max.csv')
minmax_1000.sample(5)
# Out:
#                                                     danceability    energy  \
# title
# My Curse - Killswitch Engage                            0.151924  0.959839
# Tell Me a Bedtime Story - Herbie Hancock                0.374171  0.529107
# Jamming - Bob Marley & The Wailers                      0.972357  0.432719
# Die Zauberflöte, K.620 / Act 2: "Der Hölle Rach...      0.541132  0.108416
# Ready Teddy - Little Richard                            0.522335  0.680716
#
#                                                          key  loudness  mode  \
# title
# My Curse - Killswitch Engage                        0.909091  0.912224   0.0
# Tell Me a Bedtime Story - Herbie Hancock            0.363636  0.611440   0.0
# Jamming - Bob Marley & The Wailers                  1.000000  0.706491   0.0
# Die Zauberflöte, K.620 / Act 2: "Der Hölle Rach...  0.454545  0.581610   1.0
# Ready Teddy - Little Richard                        0.454545  0.853268   1.0
#
#                                                     speechiness  acousticness  \
# title
# My Curse - Killswitch Engage                           0.077967      0.000074
# Tell Me a Bedtime Story - Herbie Hancock               0.011758      0.715863
# Jamming - Bob Marley & The Wailers                     0.498915      0.153612
# Die Zauberflöte, K.620 / Act 2: "Der Hölle Rach...     0.202243      0.974900
# Ready Teddy - Little Richard                           0.301737      0.675702
#
#                                                     instrumentalness  \
# title
# My Curse - Killswitch Engage                                0.010071
# Tell Me a Bedtime Story - Herbie Hancock                    0.948223
# Jamming - Bob Marley & The Wailers                          0.000051
# Die Zauberflöte, K.620 / Act 2: "Der Hölle Rach...          0.019797
# Ready Teddy - Little Richard                                0.000000
#
#                                                     liveness  time_signature  \
# title
# My Curse - Killswitch Engage                        0.249196            0.50
# Tell Me a Bedtime Story - Herbie Hancock            0.101939            0.75
# Jamming - Bob Marley & The Wailers                  0.113346            0.75
# Die Zauberflöte, K.620 / Act 2: "Der Hölle Rach...  0.096754            0.75
# Ready Teddy - Little Richard                        0.085347            0.75
#
#                                                      valence     tempo
# title
# My Curse - Killswitch Engage                        0.196188  0.812960
# Tell Me a Bedtime Story - Herbie Hancock            0.345349  0.439364
# Jamming - Bob Marley & The Wailers                  0.734825  0.472354
# Die Zauberflöte, K.620 / Act 2: "Der Hölle Rach...  0.254195  0.136250
# Ready Teddy - Little Richard                        0.985498  0.997829

# %% [markdown]
# ### **4.2 Standart:**

# %%
standart = StandardScaler(with_mean=True, with_std=True).set_output(transform='pandas')
scaled_1000 = standart.fit_transform(clustersongs_1000)
scaled_1000.to_csv('1000standart.csv')
scaled_1000.sample(5)
# Out:
#                                                     danceability    energy  \
# title
# We Don't Talk Anymore (feat. Selena Gomez) - Ch...      0.862931  0.243983
# One For Daddy-O - Remastered - Cannonball Adderley      0.351789 -0.213757
# Reggaetón Lento (Bailemos) - CNCO                       1.013535  1.219786
# I Wonder Why - Dion & The Belmonts                     -0.150226  0.726562
# Moondance - 2013 Remaster - Van Morrison                0.306151 -0.753110
#
#                                                          key  loudness  \
# title
# We Don't Talk Anymore (feat. Selena Gomez) - Ch... -1.173788  0.436458
# One For Daddy-O - Remastered - Cannonball Adderley -0.043750  0.550553
# Reggaetón Lento (Bailemos) - CNCO                  -0.326259  1.150265
# I Wonder Why - Dion & The Belmonts                  1.368799  1.041187
# Moondance - 2013 Remaster - Van Morrison            1.086289 -0.158953
#
#                                                         mode  speechiness  \
# title
# We Don't Talk Anymore (feat. Selena Gomez) - Ch... -1.403236     0.553916
# One For Daddy-O - Remastered - Cannonball Adderley -1.403236    -0.641498
# Reggaetón Lento (Bailemos) - CNCO                  -1.403236    -0.418663
# I Wonder Why - Dion & The Belmonts                  0.712638    -0.597395
# Moondance - 2013 Remaster - Van Morrison           -1.403236    -0.607840
#
#                                                     acousticness  \
# title
# We Don't Talk Anymore (feat. Selena Gomez) - Ch...      0.403801
# One For Daddy-O - Remastered - Cannonball Adderley      0.296993
# Reggaetón Lento (Bailemos) - CNCO                      -0.186309
# I Wonder Why - Dion & The Belmonts                      0.264951
# Moondance - 2013 Remaster - Van Morrison                0.083379
#
#                                                     instrumentalness  \
# title
# We Don't Talk Anymore (feat. Selena Gomez) - Ch...         -0.560163
# One For Daddy-O - Remastered - Cannonball Adderley         -0.560163
# Reggaetón Lento (Bailemos) - CNCO                          -0.560163
# I Wonder Why - Dion & The Belmonts                         -0.560163
# Moondance - 2013 Remaster - Van Morrison                   -0.560138
#
#                                                     liveness  time_signature  \
# title
# We Don't Talk Anymore (feat. Selena Gomez) - Ch...  0.031578        0.247138
# One For Daddy-O - Remastered - Cannonball Adderley -0.297289        0.247138
# Reggaetón Lento (Bailemos) - CNCO                   0.011024        0.247138
# I Wonder Why - Dion & The Belmonts                 -0.112301        0.247138
# Moondance - 2013 Remaster - Van Morrison           -0.153410        0.247138
#
#                                                      valence     tempo
# title
# We Don't Talk Anymore (feat. Selena Gomez) - Ch... -0.419092 -0.482015
# One For Daddy-O - Remastered - Cannonball Adderley -0.238353 -0.214617
# Reggaetón Lento (Bailemos) - CNCO                   0.825229 -0.673244
# I Wonder Why - Dion & The Belmonts                  1.489098 -0.372967
# Moondance - 2013 Remaster - Van Morrison            0.314293 -1.513887

# %% [markdown]
# ### **4.3 Robust:**

# %%
robust = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25.0, 75.0), copy=True, unit_variance=False).set_output(transform='pandas')
robust_1000 = robust.fit_transform(clustersongs_1000)
robust_1000.to_csv('1000robust.csv')
robust_1000.sample(5)
# Out:
#                                                     danceability    energy  \
# title
# Roméo et Juliette, CG 9 / Act 1: "Ah, je veux v...     -0.666153 -0.531633
# What Can I Do - Live - Tye Tribbett                    -0.835775  0.225510
# Besame Mucho - Dave Brubeck                            -0.138782 -0.523469
# Don't Give Up - Barrington Levy                         0.826523 -0.127551
# The Motto - Drake                                       0.629144 -0.178571
#
#                                                          key  loudness  mode  \
# title
# Roméo et Juliette, CG 9 / Act 1: "Ah, je veux v... -0.833333 -0.348811   0.0
# What Can I Do - Live - Tye Tribbett                -0.166667  0.288703   0.0
# Besame Mucho - Dave Brubeck                         0.833333 -0.901568  -1.0
# Don't Give Up - Barrington Levy                     0.666667 -0.215838   0.0
# The Motto - Drake                                  -0.666667  0.041243   0.0
#
#                                                     speechiness  acousticness  \
# title
# Roméo et Juliette, CG 9 / Act 1: "Ah, je veux v...     0.852752      0.717352
# What Can I Do - Live - Tye Tribbett                    0.424393     -0.467678
# Besame Mucho - Dave Brubeck                            0.287556      0.568540
# Don't Give Up - Barrington Levy                        0.934060     -0.462845
# The Motto - Drake                                      6.104115     -0.532790
#
#                                                     instrumentalness  \
# title
# Roméo et Juliette, CG 9 / Act 1: "Ah, je veux v...          0.021052
# What Can I Do - Live - Tye Tribbett                        -0.000795
# Besame Mucho - Dave Brubeck                                 4.844275
# Don't Give Up - Barrington Levy                            -0.000692
# The Motto - Drake                                          -0.000412
#
#                                                     liveness  time_signature  \
# title
# Roméo et Juliette, CG 9 / Act 1: "Ah, je veux v... -0.292075             0.0
# What Can I Do - Live - Tye Tribbett                 2.742654             0.0
# Besame Mucho - Dave Brubeck                         7.666963             0.0
# Don't Give Up - Barrington Levy                    -0.461264             0.0
# The Motto - Drake                                  -0.062333             0.0
#
#                                                      valence     tempo
# title
# Roméo et Juliette, CG 9 / Act 1: "Ah, je veux v... -0.541316 -0.738545
# What Can I Do - Live - Tye Tribbett                -0.489857 -0.606895
# Besame Mucho - Dave Brubeck                        -0.307768 -1.045145
# Don't Give Up - Barrington Levy                     0.713508  0.685643
# The Motto - Drake                                  -0.171202  2.059375

# %% [markdown]
# ### **4.4 Quantile:**

# %%
quantile = QuantileTransformer(n_quantiles=10, output_distribution='uniform', ignore_implicit_zeros=False, subsample=10000, random_state=None, copy=True).set_output(transform='pandas')
quantile_1000 = quantile.fit_transform(clustersongs_1000)
quantile_1000.to_csv('1000quantile.csv')
quantile_1000.sample(5)
# Out:
#                                             danceability    energy       key  \
# title
# Bang Bang - Jessie J                            0.734705  0.765632  0.000000
# It Never Entered My Mind - Coleman Hawkins      0.499182  0.114608  0.444444
# Morado - J Balvin                               0.945069  0.696806  1.000000
# My Prayer - The Platters                        0.223315  0.275519  0.888889
# It's Too Late - Carole King                     0.726793  0.422967  0.777778
#
#                                             loudness  mode  speechiness  \
# title
# Bang Bang - Jessie J                        0.869591   0.0     0.745826
# It Never Entered My Mind - Coleman Hawkins  0.215257   1.0     0.246222
# Morado - J Balvin                           0.897339   0.0     0.710511
# My Prayer - The Platters                    0.536567   1.0     0.073286
# It's Too Late - Carole King                 0.333822   0.0     0.061466
#
#                                             acousticness  instrumentalness  \
# title
# Bang Bang - Jessie J                            0.423591          0.000000
# It Never Entered My Mind - Coleman Hawkins      0.887225          0.684942
# Morado - J Balvin                               0.310416          0.448359
# My Prayer - The Platters                        0.702381          0.000000
# It's Too Late - Carole King                     0.522980          0.621890
#
#                                             liveness  time_signature  \
# title
# Bang Bang - Jessie J                        0.899779        0.555556
# It Never Entered My Mind - Coleman Hawkins  0.500000        0.555556
# Morado - J Balvin                           0.268054        0.555556
# My Prayer - The Platters                    0.289814        0.111111
# It's Too Late - Carole King                 0.696774        0.555556
#
#                                              valence     tempo
# title
# Bang Bang - Jessie J                        0.728898  0.828050
# It Never Entered My Mind - Coleman Hawkins  0.413674  0.719104
# Morado - J Balvin                           0.814220  0.344894
# My Prayer - The Platters                    0.284946  0.488755
# It's Too Late - Carole King                 0.822248  0.443103

# %% [markdown]
# ### **4.5 Power:**

# %%
power = PowerTransformer(method='yeo-johnson', standardize=True, copy=True).set_output(transform='pandas')
power_1000 = power.fit_transform(clustersongs_1000)
power_1000.to_csv('1000power.csv')
power_1000.sample(5)
# Out:
#                                                     danceability    energy  \
# title
# Lonely Boy - Paul Anka                                  0.330464  0.380568
# My Band - D12                                           1.511680  1.289435
# Porgy (I Loves You Porgy) - Outtake - Bill Evan...     -0.737007 -1.233561
# The Real Slim Shady - Eminem                            2.085329  0.564892
# Ridin' - Chamillionaire                                 1.181861  1.083117
#
#                                                          key  loudness  \
# title
# Lonely Boy - Paul Anka                             -1.635960 -0.076243
# My Band - D12                                       0.336531  1.513646
# Porgy (I Loves You Porgy) - Outtake - Bill Evan...  0.076116 -1.507500
# The Real Slim Shady - Eminem                        0.076116  1.155616
# Ridin' - Chamillionaire                             0.820352  1.051965
#
#                                                         mode  speechiness  \
# title
# Lonely Boy - Paul Anka                              0.712638    -1.136081
# My Band - D12                                      -1.403236     0.646938
# Porgy (I Loves You Porgy) - Outtake - Bill Evan...  0.712638    -1.161483
# The Real Slim Shady - Eminem                       -1.403236     0.049907
# Ridin' - Chamillionaire                            -1.403236     0.920779
#
#                                                     acousticness  \
# title
# Lonely Boy - Paul Anka                                 -0.212890
# My Band - D12                                           0.108376
# Porgy (I Loves You Porgy) - Outtake - Bill Evan...      1.163313
# The Real Slim Shady - Eminem                           -1.232341
# Ridin' - Chamillionaire                                -0.697749
#
#                                                     instrumentalness  \
# title
# Lonely Boy - Paul Anka                                     -0.641700
# My Band - D12                                              -0.641665
# Porgy (I Loves You Porgy) - Outtake - Bill Evan...          1.784442
# The Real Slim Shady - Eminem                               -0.641700
# Ridin' - Chamillionaire                                    -0.641700
#
#                                                     liveness  time_signature  \
# title
# Lonely Boy - Paul Anka                             -0.506420       -2.061234
# My Band - D12                                      -0.420539        0.172232
# Porgy (I Loves You Porgy) - Outtake - Bill Evan...  1.981445        0.172232
# The Real Slim Shady - Eminem                       -1.674058        0.172232
# Ridin' - Chamillionaire                             1.340837        0.172232
#
#                                                      valence     tempo
# title
# Lonely Boy - Paul Anka                              1.141312 -0.159819
# My Band - D12                                       1.374844  0.290420
# Porgy (I Loves You Porgy) - Outtake - Bill Evan... -1.126888 -0.397068
# The Real Slim Shady - Eminem                        1.030093 -0.218095
# Ridin' - Chamillionaire                             1.245432  0.930160

# %% [markdown]
# ## **5. Different Scaler for 5000 songs:**

# %%
# Taken fromabove with 1000 songs:
# MinMax:
my_min_max.fit(clustersongs_5000)
minmax_5000_df = my_min_max.transform(clustersongs_5000) 
minmax_5000 = pd.DataFrame(minmax_5000_df,
              index=clustersongs_5000.index,
              columns=clustersongs_5000.columns)
minmax_5000.to_csv('5000min_max.csv')
# Standart:
scaled_5000 = standart.fit_transform(clustersongs_5000)
scaled_5000.to_csv('5000standart.csv')
# Robust:
robust_5000 = robust.fit_transform(clustersongs_5000)
robust_5000.to_csv('5000robust.csv')
# Quantile:
quantile_5000 = quantile.fit_transform(clustersongs_5000)
quantile_5000.to_csv('5000quantile.csv')
# Power:
power_5000 = power.fit_transform(clustersongs_5000)
power_5000.to_csv('5000power.csv')
